# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
dataset = pd.read_excel('C:\\Users\\WesleyZhou\\Desktop\\CS559\\Assignment1\\data1.xlsx')

# %%
dataset
# Out:
#                                      Movie  Year  Ratings  Genre      Gross  \
# 0                                  13 Sins  2014      6.3      8       9130
# 1                           22 Jump Street  2014      7.1      1  192000000
# 2                           3 Days to Kill  2014      6.2      1   30700000
# 3                   300: Rise of an Empire  2014      6.3      1  106000000
# 4                        A Haunted House 2  2014      4.7      8   17300000
# 5                           A Long Way Off  2014      4.6      3      29000
# 6        A Million Ways to Die in the West  2014      6.1      8   42600000
# 7                      A Most Violent Year  2014      7.1      1    5750000
# 8              A Walk Among the Tombstones  2014      6.5     10   26000000
# 9                         About Last Night  2014      6.1      8   48600000
# 10                         American Sniper  2014      7.3      1  350000000
# ...

# %%
#split dataset into train and test

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
cols = ['Year','Genre','Gross','Budget','Screens','Sequel','Sentiment','Views','Likes','Dislikes','Comments','Aggregate Followers']

# %%
dataset[cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 12 columns):
# Year                   231 non-null int64
# Genre                  231 non-null int64
# Gross                  231 non-null int64
# Budget                 230 non-null float64
# Screens                221 non-null float64
# Sequel                 231 non-null int64
# Sentiment              231 non-null int64
# Views                  231 non-null int64
# Likes                  231 non-null int64
# Dislikes               231 non-null int64
# Comments               231 non-null int64
# Aggregate Followers    196 non-null float64
# dtypes: float64(3), int64(9)
# memory usage: 21.7 KB

# %%
X = dataset[cols].values
y = dataset['Ratings'].values

# %%
#X_test,y_test is for testing dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3,random_state=None)

# %%
dataX_test = X_test
datay_test = y_test

# %%
#Try to get the trainning and validation set

# %%
X = X_train
y = y_train

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3,random_state=None)

# %%
X_validation = X_test
y_validation = y_test

# %%
#len(X_validation)

# %%
#Deal with the missing value

# %%
from sklearn.preprocessing import Imputer

# %%
imp = Imputer(missing_values='NaN', strategy='mean', axis=0)

# %%
imp.fit(X_train)
X_train = imp.transform(X_train)

# %%
imp.fit(X_validation)
X_validation = imp.transform(X_validation)

# %%
imp.fit(dataX_test)
dataX_test = imp.transform(dataX_test)

# %%
# scalling the data Using MinMaxScaler

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_train_scaled = min_max_scaler.fit_transform(X_train)

# %%
X_validation_scaled = min_max_scaler.transform(X_validation)

# %%
dataX_test_scaled = min_max_scaler.transform(dataX_test)

# %%
#Using Ridge Regression Model and Lasso Regression Model

# %%
 from sklearn import linear_model

# %%
clfs = {
#     'Ridge':linear_model.Ridge (alpha = .5),
    'Lasso':linear_model.Lasso(alpha = 0.1)
}

for clf in clfs:
    try:
        clfs[clf].fit(X_train, y_train)
        y_pred = clfs[clf].predict(X_validation)
        print(clf + " mean:" + y_pred-y_test)
    except Exception as e:
        print(clf + " Error:")
        print(str(e))
# Out:
# Lasso Error:
# ufunc 'add' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')

# %%
reg = linear_model.Ridge (alpha = .5)
reg.fit(X_train,y_train)
# Out:
# D:\Anaconda3\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 1.4003545658210914e-17 / 1.1102230246251565e-16
#   RuntimeWarning)
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
reg_pred = reg.predict(dataX_test)

# %%
np.sqrt(np.mean((reg_pred-datay_test)*(reg_pred-datay_test)))
# Out:
# 0.8988041689839805

# %%
reg1 = linear_model.Lasso(alpha = 0.1)
reg1.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
reg1_pred = reg1.predict(dataX_test)

# %%
np.mean(reg1_pred-datay_test)
# Out:
# 0.07973147059880245

# %%
np.std(reg1_pred-datay_test)
# Out:
# 0.8794238615101809

# %%
np.sqrt(np.mean((reg1_pred-datay_test)*(reg1_pred-datay_test)))
# Out:
# 0.9131220734743026

# %%
# reg2 = linear_model.Lasso(alpha = 0.1)
# reg2.fit(X_train,y_train)
for x in range(0, 10):
    reg2 = linear_model.Lasso(alpha = 0.1)
    reg2.fit(X_train,y_train)
    reg2_pred = reg2.predict(dataX_test)
    print(np.mean((reg2_pred-datay_test)*(reg2_pred-datay_test))/len(reg2_pred-datay_test))
# Out:
# 0.012219556685360594
# 0.012219556685360594
# 0.012219556685360594
# 0.012219556685360594
# 0.012219556685360594
# 0.012219556685360594
# 0.012219556685360594
# 0.012219556685360594
# 0.012219556685360594
# 0.012219556685360594

# %%
#1 Latex
#2 数学符号
#3 Q5
